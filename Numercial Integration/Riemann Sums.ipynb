# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def f(x):
    return (2*x)/(1+x**2)

a = 0
b = 6
N = int((1/.001)) # STEP SIZE
n = 10

x = np.linspace(a,b,N+1)
y = f(x)

X = np.linspace(a,b,n*N+1)
Y = f(X)

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(X,Y,'b')
x_left = x[:-1]
y_left = y[:-1]
plt.plot(x_left,y_left,'b.',markersize=10)
plt.bar(x_left,y_left,width=(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Left Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,2)
plt.plot(X,Y,'b')
x_mid = (x[:-1] + x[1:])/2
y_mid = f(x_mid)
plt.plot(x_mid,y_mid,'b.',markersize=10)
plt.bar(x_mid,y_mid,width=(b-a)/N,alpha=0.2,edgecolor='b')
plt.title('Midpoint Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,3)
plt.plot(X,Y,'b')
x_right = x[1:]
y_right = y[1:]
plt.plot(x_right,y_right,'b.',markersize=10)
plt.bar(x_right,y_right,width=-(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Right Riemann Sum, N = {}'.format(N))

plt.show()

# %%
dx = (b-a)/N
x_left = np.linspace(a,b-dx,N)
x_midpoint = np.linspace(dx/2,b - dx/2,N)
x_right = np.linspace(dx,b,N)

actual = 3.6109179126442244
print("Actual:", actual)

left_riemann_sum = np.sum(f(x_left) * dx)
print("\nLeft Riemann Sum:",left_riemann_sum, "\nDifference: ", abs(actual-left_riemann_sum))

midpoint_riemann_sum = np.sum(f(x_midpoint) * dx)
print("\nMidpoint Riemann Sum:",midpoint_riemann_sum, "\nDifference: ", abs(actual-midpoint_riemann_sum))

right_riemann_sum = np.sum(f(x_right) * dx)
print("\nRight Riemann Sum:",right_riemann_sum, "\nDifference: ", abs(actual-right_riemann_sum))
# Out:
# Actual: 3.6109179126442243
#
# Left Riemann Sum: 3.6099387862530232
# Difference:  0.0009791263912011239
#
# Midpoint Riemann Sum: 3.610920989361434
# Difference:  3.0767172094492423e-06
#
# Right Riemann Sum: 3.6118847321989698
# Difference:  0.0009668195547454239
